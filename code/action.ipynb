# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
import seaborn as sns

# %%
movies=pd.read_csv("C:/Users/shinyoungmin/Desktop/수DA쟁이/과제/조별과제/영화 관객수/movies.csv")

# %%
action=movies[movies.genre.isin(['느와르','액션'])]

# %%
np.size(action,axis=0)
# Out:
# 55

# %%
rate=np.zeros(shape=(55),dtype=np.int8)

# %%
rate_o=list(action.screening_rat)

# %%
for it in range(55):
    if rate_o[it]=='12세 관람가':
        rate[it]=1
    elif rate_o[it]=='15세 관람가':
        rate[it]=2
    elif rate_o[it]=='청소년 관람불가':
        rate[it]=3

# %%
action=action.reset_index(inplace=False)

# %%
action=action.drop('screening_rat',axis=1)

# %%
action['screeing_rat']=rate

# %%
action
# Out:
#     index               title    distributor genre release_time  time  \
# 0       0              개들의 전쟁       롯데엔터테인먼트    액션   2012-11-22    96
# 1       1                내부자들         (주)쇼박스   느와르   2015-11-19   130
# 2       2           은밀하게 위대하게         (주)쇼박스    액션   2013-06-05   123
# 3       7                 회사원         (주)쇼박스    액션   2012-10-11    96
# 4      28                 무법자         (주)NEW   느와르   2010-03-18    93
# 5      44                부당거래      CJ 엔터테인먼트   느와르   2010-10-28   119
# 6      48                 빅매치         (주)NEW    액션   2014-11-26   112
# 7      59                친구 2       롯데엔터테인먼트   느와르   2013-11-14   124
# 8      74                 아저씨      CJ 엔터테인먼트    액션   2010-08-04   119
# 9      91                 무적자      CJ 엔터테인먼트    액션   2010-09-16   124
# 10     96                 잉투기          무비꼴라쥬    액션   2013-11-14    98
# 11    100                 26년          인벤트 디    액션   2012-11-29   135
# 12    112  범죄와의 전쟁: 나쁜놈들 전성시대         (주)쇼박스   느와르   2012-02-02   133
# 13    139                 고지전         (주)쇼박스    액션   2011-07-20   133
# 14    141     하이프 네이션 : 힙합사기꾼          인벤트 디   느와르   2014-01-16    84
# 15    169              아이들...       롯데엔터테인먼트   느와르   2011-02-17   132
# 16    175           악인은 너무 많다            어뮤즈   느와르   2011-12-15    75
# 17    179                 응징자          인벤트 디    액션   2013-10-30   103
# 18    182                  혈투             KT    액션   2011-02-24   111
# 19    188        권법형사 : 차이나타운       골든타이드픽처스    액션   2015-07-09    83
# 20    198     18: 우리들의 성장 느와르            어뮤즈   느와르   2014-08-14   104
# 21    201             강남 1970         (주)쇼박스    액션   2015-01-21   135
# 22    220                 런닝맨   이십세기폭스코리아(주)    액션   2013-04-04   127
# 23    226             육혈포 강도단        전망좋은영화사   느와르   2010-03-18   107
# 24    239      개: dog eat dog          어썸 피플   느와르   2015-03-05   101
# 25    248           철암 계곡의 혈투          인디스토리    액션   2012-07-12    89
# 26    254                 특수본       롯데엔터테인먼트    액션   2011-11-24   111
# 27    268             분노의 윤리학       롯데엔터테인먼트   느와르   2013-02-21   110
# 28    320              최종병기 활       롯데엔터테인먼트    액션   2011-08-10   122
# 29    358               카운트다운            NEW    액션   2011-09-29   119
# 30    361                 더 폰         (주)NEW    액션   2015-10-22   114
# 31    362                 도둑들         (주)쇼박스   느와르   2012-07-25   135
# 32    367                치외법권        판씨네마(주)    액션   2015-08-27   104
# 33    377        내부자들: 디 오리지널         (주)쇼박스   느와르   2015-12-31   180
# 34    388                공모자들   씨너스엔터테인먼트(주)   느와르   2012-08-29   111
# 35    422              전설의 주먹      CJ 엔터테인먼트    액션   2013-04-10   153
# 36    424                  짐승        (주)키노아이    액션   2011-07-28    93
# 37    429              신의 한 수         (주)쇼박스   느와르   2014-07-03   118
# 38    442             악마를 보았다         (주)쇼박스   느와르   2010-08-12   144
# 39    472                감시자들         (주)NEW   느와르   2013-07-03   119
# 40    473              성난 변호사      CJ 엔터테인먼트   느와르   2015-10-08   117
# 41    477                  황해         (주)쇼박스   느와르   2010-12-22   156
# 42    485              끝까지 간다         (주)쇼박스   느와르   2014-05-29   111
# 43    491         R2B: 리턴투베이스          주머니필름    액션   2012-08-15   113
# 44    498                  암살         (주)쇼박스    액션   2015-07-22   139
# 45    516                서부전선       롯데엔터테인먼트    액션   2015-09-24   112
# 46    519                 보호자          무비꼴라쥬   느와르   2014-04-10    88
# 47    524                코인라커  (주)드림팩트엔터테인먼트   느와르   2015-05-28    95
# 48    540                  헤드       SBS콘텐츠허브    액션   2011-05-26   100
# 49    543           협녀, 칼의 기억       롯데엔터테인먼트    액션   2015-08-13   121
# 50    583                  창수  (주)마인스 엔터테인먼트   느와르   2013-11-28   103
# 51    588                 하울링      CJ 엔터테인먼트   느와르   2012-02-16   114
# 52    592               차이나타운       CGV아트하우스   느와르   2015-04-29   110
# 53    598              악의 연대기      CJ 엔터테인먼트   느와르   2015-05-14   102
# 54    599                 베를린      CJ 엔터테인먼트    액션   2013-01-30   120
#
#    director  dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num  \
# 0       조병옥             NaN             0         91          2        23398
# 1       우민호    1.161602e+06             2        387          3      7072501
# 2       장철수    2.207752e+05             4        343          4      6959083
# 3       임상윤    7.395220e+05             3        342          2      1110523
# 4       김철한             NaN             0        250          3       160734
# 5       류승완             NaN             0        471          4      2723028
# 6        최호    1.159954e+06             2        600          4      1177435
# 7       곽경택    3.728630e+05             2        319          3      2971475
# 8       이정범             NaN             0        509          2      6178665
# 9       송해성    1.163526e+06             3        546          4      1546132
# 10      엄태화             NaN             0         65          3        17341
# 11      조근현    2.636385e+06             1        365          3      2963652
# 12      윤종빈    7.195870e+05             1        308          2      4720050
# 13       장훈    2.266504e+06             3        238         11      2945151
# 14      박형우             NaN             0          6          3         3996
# 15      이규만             NaN             0        423          5      1867849
# 16      김회근    1.681556e+06             2         26          4          809
# 17      신재호    4.444850e+04             2        151          3       192347
# 18      박훈정    2.270048e+06             2        306          3        43947
# 19      박상현             NaN             0        151          2          257
# 20      한윤선    3.534800e+04             1        126          3         1124
# 21       유하    1.949111e+06             4        719          3      2192276
# 22      조동오    4.738523e+05             3        307          5      1422844
# 23      강효진    3.751800e+04             1        318          3      1214237
# 24       황욱             NaN             0         58          5         1504
# 25      지하진             NaN             0          5          2         1002
# 26      황병국             NaN             0        253          6      1118258
# 27      박명랑    1.511050e+05             1        215          5       225618
# 28      김한민    2.079989e+06             1        687          4      7482180
# 29      허종호    1.086916e+06             2        109          2       471547
# 30      김봉주    2.500135e+06             4        437          3      1596762
# 31      최동훈    2.564692e+06             3        462         10     12983841
# 32      신재호    9.374800e+04             3        253          2       346483
# 33      우민호    3.131902e+06             3        382          3      2084844
# 34      김홍선             NaN             0        284          4      1646142
# 35      강우석    8.448210e+05             3        335          6      1744585
# 36      황유식    5.064190e+05             2         54          2          480
# 37      조범구    1.731903e+06             2        418          5      3566844
# 38      김지운             NaN             0        582          2      1817069
# 39      조의석    8.074100e+04             2        331          3      5508299
# 40      허종호    8.817930e+05             3        431          3      1131154
# 41      나홍진    5.046096e+06             1        683          3      2260512
# 42      김성훈    4.361015e+05             2        343          2      3450305
# 43      김동원             NaN             0        477          7      1201944
# 44      최동훈    5.169479e+06             4        628          3     12706663
# 45      천성일    4.385472e+06             2        388          2       609063
# 46      유원상    2.496000e+03             1        128          3          458
# 47      김태경    2.283850e+05             1        115          2         1008
# 48       조운    1.450000e+02             1        290          3        61414
# 49      박흥식    1.209303e+05             3        439          3       431310
# 50      이덕희    2.810000e+02             1        194          5       429141
# 51       유하    2.061297e+06             3        288          2      1612554
# 52      한준희    5.974970e+05             3        420          3      1472147
# 53      백운학             NaN             0        431          4      2192525
# 54      류승완             NaN             0        363          5      7166532
#
#     screeing_rat
# 0              3
# 1              3
# 2              2
# 3              3
# 4              3
# 5              3
# 6              2
# 7              3
# 8              3
# 9              2
# 10             2
# 11             2
# 12             3
# 13             2
# 14             3
# 15             2
# 16             3
# 17             3
# 18             2
# 19             3
# 20             3
# 21             3
# 22             2
# 23             2
# 24             3
# 25             3
# 26             2
# 27             3
# 28             2
# 29             3
# 30             2
# 31             2
# 32             2
# 33             3
# 34             3
# 35             3
# 36             3
# 37             3
# 38             3
# 39             2
# 40             2
# 41             3
# 42             2
# 43             2
# 44             2
# 45             1
# 46             2
# 47             3
# 48             3
# 49             2
# 50             3
# 51             2
# 52             3
# 53             2
# 54             2

# %%
Y=action.box_off_num.values
X=action.screeing_rat.values

# %%
plt.scatter(X,Y)

# %%
np.cov(X,Y)[0,1]
# Out:
# -370484.996969697

# %%
np.corrcoef(X,Y)[0,1]
# Out:
# -0.23424809556239914

# %%
import scipy.stats as stats
stats.pearsonr(X,Y)
# Out:
# (-0.234248095562399, 0.08518398795546853)
